# %%
# !pip install bs4==0.0.2
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests 
import time
import random

# %%
date = []
country = []
reviews = []
stars = []

# %%
for i in range(1,350):
    page=requests.get(f"https://www.airlinequality.com/airline-reviews/united-airlines/page/{i}/")
    soup=BeautifulSoup(page.content, "html.parser")
    
    for item in soup.find_all("div",class_="text_content"):
        reviews.append(item.text)
    for item in soup.find_all("div",class_="rating-10"):
        try:
            stars.append(item.span.text)
        except:
            print(f"Error found on page {i}")
            stars.append("None")
    for item in soup.find_all("time"):
        date.append(item.text)
    for item in soup.find_all("h3"):
        country.append(item.span.next_sibling.text.strip(" ()"))

# %%
len(country)
# Out:
# 1580

# %%
len(stars)
# Out:
# 1738

# %%
len(reviews)
# Out:
# 1580

# %%
len(date)
# Out:
# 1580

# %%
country=country[:580]
reviews=reviews[:580]
stars=stars[:580]
date=date[:580]

# %%
len(date)
# Out:
# 580

# %%
df=pd.DataFrame({"Reviews": reviews,"Date": date,"Stars": stars,"Country": country})

# %%
df.to_csv("United_Airlines_reviews.csv",index=False)

# %%
df
# Out:
#                                                Reviews               Date  \
# 0    ✅ Trip Verified |   We paid serious money for ...  10th October 2024
# 1    ✅ Trip Verified |   The first half of the flig...   9th October 2024
# 2    ✅ Trip Verified | I booked a roundtrip with Un...   8th October 2024
# 3    ✅ Trip Verified |   Fifteen hours of abject mi...   5th October 2024
# 4    ✅ Trip Verified |   With all the negative stuf...   3rd October 2024
# ..                                                 ...                ...
# 575  ✅ Trip Verified |  Newark to Los Angeles. 5 ho...     29th July 2018
# 576  ✅ Trip Verified |  Newark to Rochester. The mo...     28th July 2018
# 577  ✅ Trip Verified |  El Paso  to Houston. My fam...     27th July 2018
# 578  ✅ Trip Verified |  \r\nPhoenix to Denver. Unit...     27th July 2018
# 579  Not Verified |  Venice to Newark. Our 10:55 am...     27th July 2018
#
#                            Stars        Country
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0d4583b4-0590-436d-87dc-0521c05936e7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
